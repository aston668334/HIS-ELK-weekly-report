# %%
from datavisualization import Docker, Postgres, APM

# %%
# docker_memory = Docker.DockerMemory('his-training')
# docker_memory.prepare_plot()
# docker_memory.show_plot()
# docker_memory.save_plot()

# %%
# docker_cpu = Docker.DockerCPU('his-training')
# docker_cpu.prepare_plot()
# docker_cpu.show_plot()
# docker_cpu.save_plot()

# %%
apm_cpu = APM.JVMCPU('histesting')
apm_cpu.prepare_plot()
# apm_cpu.show_plot()
# apm_cpu.save_plot()
# Out:
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:399: SecurityWarning: Connecting to 'https://192.168.101.11:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host '192.168.101.11'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#                         timestamp   timestamp_ms  doc_count   value_1  \
# 0   2024-05-31T12:00:00.000-04:00  1717171200000        405  0.013956
# 1   2024-05-31T18:00:00.000-04:00  1717192800000       2160  0.013581
# 2   2024-06-01T00:00:00.000-04:00  1717214400000       2160  0.013563
# 3   2024-06-01T06:00:00.000-04:00  1717236000000       2160  0.013002
# 4   2024-06-01T12:00:00.000-04:00  1717257600000       2160  0.013042
# 5   2024-06-01T18:00:00.000-04:00  1717279200000       2160  0.013519
# 6   2024-06-02T00:00:00.000-04:00  1717300800000       2160  0.013564
# 7   2024-06-02T06:00:00.000-04:00  1717322400000       2160  0.013535
# 8   2024-06-02T12:00:00.000-04:00  1717344000000       2160  0.013525
# 9   2024-06-02T18:00:00.000-04:00  1717365600000       2072  0.011457
# 10  2024-06-03T00:00:00.000-04:00  1717387200000       2160  0.013594
# 11  2024-06-03T06:00:00.000-04:00  1717408800000       2160  0.014740
# 12  2024-06-03T12:00:00.000-04:00  1717430400000       2160  0.015292
# 13  2024-06-03T18:00:00.000-04:00  1717452000000       2160  0.013748
# 14  2024-06-04T00:00:00.000-04:00  1717473600000       2160  0.008396
# 15  2024-06-04T06:00:00.000-04:00  1717495200000       2160  0.012065
# 16  2024-06-04T12:00:00.000-04:00  1717516800000       2160  0.015938
# 17  2024-06-04T18:00:00.000-04:00  1717538400000       2160  0.013923
# 18  2024-06-05T00:00:00.000-04:00  1717560000000       2160  0.013922
# 19  2024-06-05T06:00:00.000-04:00  1717581600000       2160  0.012590
# 20  2024-06-05T12:00:00.000-04:00  1717603200000       2160  0.015247
# 21  2024-06-05T18:00:00.000-04:00  1717624800000       2160  0.014031
# 22  2024-06-06T00:00:00.000-04:00  1717646400000       2160  0.014034
# 23  2024-06-06T06:00:00.000-04:00  1717668000000       1959  0.016911
# 24  2024-06-06T12:00:00.000-04:00  1717689600000       1905  0.016815
# 25  2024-06-06T18:00:00.000-04:00  1717711200000       2067  0.015437
# 26  2024-06-07T00:00:00.000-04:00  1717732800000        387  0.055010
# 27  2024-06-07T06:00:00.000-04:00  1717754400000       2098  0.013751
# 28  2024-06-07T12:00:00.000-04:00  1717776000000       1709  0.007197
#
#      value_2       value_3  value_4   value_5   value_6
# 0   0.005726  0.000000e+00      0.0  0.000035  0.003237
# 1   0.005444  0.000000e+00      0.0  0.000031  0.002286
# 2   0.005438  4.629630e-07      0.0  0.000030  0.002647
# 3   0.005350  9.259259e-07      0.0  0.000026  0.002751
# 4   0.005334  0.000000e+00      0.0  0.000035  0.002588
# 5   0.005453  0.000000e+00      0.0  0.000026  0.002400
# 6   0.005438  9.259259e-07      0.0  0.000026  0.002374
# 7   0.005414  9.259259e-07      0.0  0.000032  0.002193
# 8   0.005427  0.000000e+00      0.0  0.000023  0.002407
# 9   0.005101  0.000000e+00      0.0  0.000017  0.002575
# 10  0.005449  1.388889e-06      0.0  0.000026  0.002107
# 11  0.005806  0.000000e+00      0.0  0.000065  0.006031
# 12  0.005874  0.000000e+00      0.0  0.000070  0.004205
# 13  0.005542  0.000000e+00      0.0  0.000018  0.002343
# 14  0.004753  0.000000e+00      0.0  0.000010  0.002304
# 15  0.005294  9.259259e-07      0.0  0.000046  0.003348
# 16  0.006013  0.000000e+00      0.0  0.000065  0.003413
# 17  0.005718  0.000000e+00      0.0  0.000030  0.002169
# 18  0.005711  4.629630e-07      0.0  0.000028  0.002344
# 19  0.005628  9.259259e-07      0.0  0.000049  0.003989
# 20  0.006056  0.000000e+00      0.0  0.000057  0.003469
# 21  0.005852  0.000000e+00      0.0  0.000043  0.002288
# 22  0.005844  9.259259e-07      0.0  0.000026  0.002379
# 23  0.011341  0.000000e+00      0.0  0.000209  0.068266
# 24  0.011715  0.000000e+00      0.0  0.000225  0.094355
# 25  0.009695  0.000000e+00      0.0  0.000129  0.040853
# 26  0.095874  0.000000e+00      0.0  0.001673  0.631893
# 27  0.009005  9.541985e-07      0.0  0.000205  0.083359
# 28  0.004255  0.000000e+00      0.0  0.000008  0.002339

# %%
apm_memory = APM.JVMMemory('histesting')
apm_memory.prepare_plot()
apm_memory.show_plot()
apm_memory.save_plot()
# Out:
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:399: SecurityWarning: Connecting to 'https://192.168.101.11:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host '192.168.101.11'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
postgreslongquery = Postgres.PostgresLongQuery('his-training')
postgreslongquery.get_dataframe()
# Out:
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:399: SecurityWarning: Connecting to 'https://192.168.101.11:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host '192.168.101.11'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     postgresql.log.query_name elastic_agent.version event.category  \
# 0                      [S_28]               [8.8.2]     [database]
# 1                      [S_28]               [8.8.2]     [database]
# 2                       [S_3]               [8.8.2]     [database]
# 3                 [<unnamed>]               [8.8.2]     [database]
# 4                 [<unnamed>]               [8.8.2]     [database]
# ..                        ...                   ...            ...
# 203               [<unnamed>]               [8.8.2]     [database]
# 204                     [S_3]               [8.8.2]     [database]
# 205               [<unnamed>]               [8.8.2]     [database]
# 206                     [S_3]               [8.8.2]     [database]
# 207               [<unnamed>]               [8.8.2]     [database]
#
#       host.os.name.text   host.hostname process.pid  \
# 0    [Debian GNU/Linux]  [his-training]     [80287]
# 1    [Debian GNU/Linux]  [his-training]     [80287]
# 2    [Debian GNU/Linux]  [his-training]        [49]
# 3    [Debian GNU/Linux]  [his-training]     [80287]
# 4    [Debian GNU/Linux]  [his-training]     [80287]
# ..                  ...             ...         ...
# 203  [Debian GNU/Linux]  [his-training]     [39200]
# 204  [Debian GNU/Linux]  [his-training]        [49]
# 205  [Debian GNU/Linux]  [his-training]     [39200]
# 206  [Debian GNU/Linux]  [his-training]        [49]
# 207  [Debian GNU/Linux]  [his-training]     [39200]
#
#                                    host.mac               container.id  \
# 0    [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 1    [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 2    [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 3    [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 4    [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# ..                                      ...                        ...
# 203  [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 204  [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 205  [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 206  [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
# 207  [02-42-06-98-5B-75, 3A-3A-3B-BE-74-54]  [hisdeploy_postgres_logs]
#
#      host.os.version postgresql.log.sql_state_code  ...  \
# 0    [12 (bookworm)]                       [00000]  ...
# 1    [12 (bookworm)]                       [00000]  ...
# 2    [12 (bookworm)]                       [00000]  ...
# 3    [12 (bookworm)]                       [00000]  ...
# 4    [12 (bookworm)]                       [00000]  ...
# ..               ...                           ...  ...
# 203  [12 (bookworm)]                       [00000]  ...
# 204  [12 (bookworm)]                       [00000]  ...
# 205  [12 (bookworm)]                       [00000]  ...
# 206  [12 (bookworm)]                       [00000]  ...
# 207  [12 (bookworm)]                       [00000]  ...
#
#                      @timestamp postgresql.log.application_name  \
# 0    [2024-06-07T16:24:38.902Z]               [his_ambulatoria]
# 1    [2024-06-07T16:24:05.688Z]               [his_ambulatoria]
# 2    [2024-06-07T16:22:48.536Z]               [his_ambulatoria]
# 3    [2024-06-07T16:22:46.855Z]               [his_ambulatoria]
# 4    [2024-06-07T15:57:59.664Z]               [his_ambulatoria]
# ..                          ...                             ...
# 203  [2024-06-03T11:13:29.595Z]               [his_ambulatoria]
# 204  [2024-06-02T02:59:37.498Z]               [his_ambulatoria]
# 205  [2024-06-02T02:59:35.806Z]               [his_ambulatoria]
# 206  [2024-06-01T10:14:48.887Z]               [his_ambulatoria]
# 207  [2024-06-01T10:14:47.194Z]               [his_ambulatoria]
#
#     host.os.platform event.type  \
# 0           [debian]     [info]
# 1           [debian]     [info]
# 2           [debian]     [info]
# 3           [debian]     [info]
# 4           [debian]     [info]
# ..               ...        ...
# 203         [debian]     [info]
# 204         [debian]     [info]
# 205         [debian]     [info]
# 206         [debian]     [info]
# 207         [debian]     [info]
#
#                                          log.file.path data_stream.dataset  \
# 0    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 1    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 2    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 3    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 4    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# ..                                                 ...                 ...
# 203  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 204  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 205  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 206  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 207  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
#
#                          agent.ephemeral_id postgresql.log.client_port  \
# 0    [08f57a4b-d62e-422f-a414-01f96471e755]                    [51902]
# 1    [08f57a4b-d62e-422f-a414-01f96471e755]                    [51902]
# 2    [08f57a4b-d62e-422f-a414-01f96471e755]                    [53160]
# 3    [08f57a4b-d62e-422f-a414-01f96471e755]                    [51902]
# 4    [08f57a4b-d62e-422f-a414-01f96471e755]                    [51902]
# ..                                      ...                        ...
# 203  [08f57a4b-d62e-422f-a414-01f96471e755]                    [56860]
# 204  [08f57a4b-d62e-422f-a414-01f96471e755]                    [53160]
# 205  [08f57a4b-d62e-422f-a414-01f96471e755]                    [56860]
# 206  [08f57a4b-d62e-422f-a414-01f96471e755]                    [53160]
# 207  [08f57a4b-d62e-422f-a414-01f96471e755]                    [56860]
#
#         event.dataset user.name.text
# 0    [postgresql.log]     [postgres]
# 1    [postgresql.log]     [postgres]
# 2    [postgresql.log]     [postgres]
# 3    [postgresql.log]     [postgres]
# 4    [postgresql.log]     [postgres]
# ..                ...            ...
# 203  [postgresql.log]     [postgres]
# 204  [postgresql.log]     [postgres]
# 205  [postgresql.log]     [postgres]
# 206  [postgresql.log]     [postgres]
# 207  [postgresql.log]     [postgres]
#
# [208 rows x 62 columns]
