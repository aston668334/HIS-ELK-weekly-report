# %%
from elasticsearch import Elasticsearch
import json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dotenv import load_dotenv 
import os
load_dotenv()

from datavisualization import Docker, Postgres
# Out:
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# docker_cpu = Docker.DockerCPU()
# docker_cpu.prepare_plot()
# docker_cpu.show_plot()
# docker_cpu.save_plot()

# %%
postgreslongquery = Postgres.PostgresLongQuery()
postgreslongquery.get_dataframe()
# Out:
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/elasticsearch/_sync/client/__init__.py:399: SecurityWarning: Connecting to 'https://192.168.101.11:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /Users/liguanwei/Github/HIS-ELK-weekly-report/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host '192.168.101.11'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#     postgresql.log.query_name event.category elastic_agent.version  \
# 0                 [<unnamed>]     [database]               [8.8.2]
# 1                 [<unnamed>]     [database]               [8.8.2]
# 2                         NaN     [database]               [8.8.2]
# 3                         NaN     [database]               [8.8.2]
# 4                 [<unnamed>]     [database]               [8.8.2]
# ..                        ...            ...                   ...
# 591               [<unnamed>]     [database]               [8.8.2]
# 592               [<unnamed>]     [database]               [8.8.2]
# 593               [<unnamed>]     [database]               [8.8.2]
# 594               [<unnamed>]     [database]               [8.8.2]
# 595               [<unnamed>]     [database]               [8.8.2]
#
#       host.os.name.text host.hostname process.pid  \
# 0    [Debian GNU/Linux]  [histesting]     [47948]
# 1    [Debian GNU/Linux]  [histesting]     [47929]
# 2    [Debian GNU/Linux]  [histesting]        [55]
# 3    [Debian GNU/Linux]  [histesting]        [56]
# 4    [Debian GNU/Linux]  [histesting]     [47901]
# ..                  ...           ...         ...
# 591  [Debian GNU/Linux]  [histesting]     [11461]
# 592  [Debian GNU/Linux]  [histesting]     [11461]
# 593  [Debian GNU/Linux]  [histesting]     [11461]
# 594  [Debian GNU/Linux]  [histesting]     [11462]
# 595  [Debian GNU/Linux]  [histesting]     [11461]
#
#                                               host.mac  \
# 0    [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 1    [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 2    [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 3    [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 4    [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# ..                                                 ...
# 591  [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 592  [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 593  [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 594  [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
# 595  [02-42-46-2E-39-BD, 02-42-BC-54-9B-CD, 72-9C-5...
#
#                   container.id  host.os.version postgresql.log.sql_state_code  \
# 0    [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 1    [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 2    [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 3    [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 4    [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# ..                         ...              ...                           ...
# 591  [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 592  [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 593  [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 594  [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
# 595  [hisdeploy_postgres_logs]  [12 (bookworm)]                       [00000]
#
#      ... host.os.platform event.type  \
# 0    ...         [debian]     [info]
# 1    ...         [debian]     [info]
# 2    ...         [debian]     [info]
# 3    ...         [debian]     [info]
# 4    ...         [debian]     [info]
# ..   ...              ...        ...
# 591  ...         [debian]     [info]
# 592  ...         [debian]     [info]
# 593  ...         [debian]     [info]
# 594  ...         [debian]     [info]
# 595  ...         [debian]     [info]
#
#                                          log.file.path data_stream.dataset  \
# 0    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 1    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 2    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 3    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 4    [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# ..                                                 ...                 ...
# 591  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 592  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 593  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 594  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
# 595  [/var/lib/docker/volumes/hisdeploy_postgres_lo...    [postgresql.log]
#
#     postgresql.log.client_port                      agent.ephemeral_id  \
# 0                      [51141]  [348607b3-4734-42dc-b466-dcea2c8951c5]
# 1                      [51079]  [348607b3-4734-42dc-b466-dcea2c8951c5]
# 2                      [47308]  [348607b3-4734-42dc-b466-dcea2c8951c5]
# 3                      [47316]  [348607b3-4734-42dc-b466-dcea2c8951c5]
# 4                      [56584]  [348607b3-4734-42dc-b466-dcea2c8951c5]
# ..                         ...                                     ...
# 591                    [40128]  [519313de-c266-4364-9197-6e99753b7294]
# 592                    [40128]  [519313de-c266-4364-9197-6e99753b7294]
# 593                    [40128]  [519313de-c266-4364-9197-6e99753b7294]
# 594                    [40138]  [519313de-c266-4364-9197-6e99753b7294]
# 595                    [40128]  [519313de-c266-4364-9197-6e99753b7294]
#
#         event.dataset user.name.text    log.flags  \
# 0    [postgresql.log]     [postgres]          NaN
# 1    [postgresql.log]     [postgres]          NaN
# 2    [postgresql.log]        [aston]          NaN
# 3    [postgresql.log]        [aston]          NaN
# 4    [postgresql.log]     [postgres]  [multiline]
# ..                ...            ...          ...
# 591  [postgresql.log]     [postgres]          NaN
# 592  [postgresql.log]     [postgres]          NaN
# 593  [postgresql.log]     [postgres]          NaN
# 594  [postgresql.log]     [postgres]          NaN
# 595  [postgresql.log]     [postgres]          NaN
#
#                                  postgresql.log.detail
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    [parameters: $1 = '0004000.00010101', $2 = '91...
# ..                                                 ...
# 591                       [parameters: $1 = '5674646']
# 592                       [parameters: $1 = '1128963']
# 593                        [parameters: $1 = '166666']
# 594                          [parameters: $1 = '1666']
# 595                        [parameters: $1 = '166666']
#
# [596 rows x 63 columns]
